# %% [markdown]
# # Simple web scraper

# %%
>>> import urllib2
>>> urllib2.urlopen("http://www.python.org/")

# %% [markdown]
# The scraper will use Python’s **BeautifulSoup** toolkit to **parse the HTML and extract the data**.
#
# We’ll also use the **Requests library** to **open the URL, download the HTML and pass it to BeautifulSoup**.

# %% [markdown]
# **Detective work**:
#
#  - http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp Web page,
#  - “View Source",
#  - ‘inspect element.’
#
# **find a pattern or identifier in the code for the elements you’d like to extract**. In the best cases, you can extract content by using the **id or class** already assigned to the element you’d like to extract.
#  - An ‘id’ is intended to act as the unique identifer of a specific item on a page.
#   - A ‘class’ is used to label a specific TYPE of item on a page. So, there may be instances of a class on a page.

# %%
import requests

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content
print (html)
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>        <title>Current Detainees of Boone County Jail</title>\n        <meta content="IE=edge" http-equiv="X-UA-Compatible" />\n        <meta content="width=device-width, initial-scale=1.0" name="viewport" />\n<!--  -->\n<!-- MultipleRecordApp: CURRENT DETAINEES. Created: Thu Apr 06 13:51:13 CDT 2017 by ITBRANDO. INQHTM-MUL 20120709 -->\n        <link href="/mrcjava/mrcclasses/SH01_MP/favicon.ico" rel="shortcut icon" />\n        <link href="/mrcjava/mrcclasses/mrc_servlet_ajax.css" rel="stylesheet" type="text/css" />\n        <link href="/mrcjava/mrcclasses/SH01_MP/mrc_default.css?v=0.74" mrcfile="150" rel="stylesheet" type="text/css" />\n        <link href="/mrcjava/mrcclasses/jquery.custom.css" rel="stylesheet" type="text/css" />\n<!--[if !IE]>\n<link href="/mrcjava/mrcclasses/mrc-responsive.css" rel="stylesheet" />\n<![endif]-->\n<!--[if IE 7]>\n<link href="/mrcjava/mrcclasses/font/css/font-awesome-ie7.css" rel="stylesheet" />\n<![endif]-->\n        <style type="text/css">#sort_table_head a {pointer-events: none;}\n          #sort_table_head i {display: none;}\n      #sort_table_head [data-col="LASTNP"] a, \n      #sort_table_head [data-col="FIRSTP"] a {\n            pointer-events: initial;}\n      #sort_table_head [data-col="LASTNP"] i, \n      #sort_table_head [data-col="FIRSTP"] i {\n            display: initial;}\n          .viewCount {text-align: center;}\n          .filterOptions.mobileOnly {display: none;}\n          /*@media screen and (min-width: 761px) {\n            body > div.ui-dialog {\n              top: 50% !important;\n              transform: translateY(-50%);\n            }\n          }*/</style>\n<script type="text/javascript" src="/mrcjava/mrcclasses/mpowerapps.js"></script>\n<script type="text/javascript" src="/mrcjava/mrcclasses/SH01_MP/js/mobileSortAndFilter.js" mrcfile="mobileSortAndFilter.js"></script>\n<script type="text/javascript" src="/mrcjava/mrcclasses/SH01_MP/js/websiteNotification.js" mrcfile="websiteNotification.js"></script>\n<script type="text/javascript">\n      var s1 = new Image().src = \'/mrcjava/image/ascg.gif\',\n          s0 = new Image().src = \'/mrcjava/image/descg.gif\';\n    </script>\n    </head>\n\n    <body>\n<!-- Begin mrc Header -->\n        <div class="page-wrap">\n<!---->\n<!-- Begin mrc Default Desktop Header -->\n<!-- Begin JavaScript Required Message -->\n<noscript>\n\t<div class="warning noJS">\n\t\tThe Boone County website <strong>requires</strong> JavaScript to function correctly. Please enable JavaScript in your browser.\n\t</div>\n</noscript>\n<!-- End JavaScript Required Message -->\n<!-- Begin Image Bar -->\n<div class="pageHeader DepartmentHeader container">\n  <div class="DepartmentHeaderGraphic">\n    <img src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg" alt="Boone County Sheriff\'s Badge" />\n  </div>\n  <div class="DepartmentHeaderInfo">\n    <div class="DepartmentHeaderTitle">\n      Boone County Sheriff\'s Department\n    </div>\n    <div class="container">\n      <div class="DepartmentHeaderAddress">\n        Boone County Sheriff\'s Department<br />\n        2121 County Dr.<br />\n        Columbia, MO 65202\n      </div>\n      <div class="DepartmentHeaderNumbers">\n        Office (573) 875-1111<br />\n        Fax (573) 874-8953\n      </div>\n    </div>\n  </div>\n</div>  \n<!-- End Image Bar -->\n<!-- Begin Link Bar -->\n<div id="headerMenu" class="container noPrint">\n  <ul>\n    <li>\n      <a href="http://www.boonecountymo.org/sheriff">\n        Home\n      </a>\n    </li>\n    <li class="mainMenu">\n      <a href="/mrcjava/servlet/SH01_MP.I00040s">\n        Menu\n      </a>\n    </li>\n    <li>\n      <a class="" href="/mrcjava/servlet/SH01_MP.I00030s" target="_new">\n        Help\n      </a>\n    </li>\n    <!--<li class="options">\n      <a href="#"  onclick="viewOptions();">\n        Options\n      </a>\n    </li>-->\n  </ul>\n</div>\n<!-- End Link Bar -->\n<!-- End mrc Default Desktop Header -->\n<!-- Be ...

# %% [markdown]
# you should see the entire HTML of the page spilled out.
#
# **Import the BeautifulSoup HTML parsing library and feed it the page**.

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html) # NEW CODE
print (soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Current Detainees of Boone County Jail
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <!-- -->
#   <!-- MultipleRecordApp: CURRENT DETAINEES. Created: Thu Apr 06 13:51:13 CDT 2017 by ITBRANDO. INQHTM-MUL 20120709 -->
#   <link href="/mrcjava/mrcclasses/SH01_MP/favicon.ico" rel="shortcut icon"/>
#   <link href="/mrcjava/mrcclasses/mrc_servlet_ajax.css" rel="stylesheet" type="text/css"/>
#   <link href="/mrcjava/mrcclasses/SH01_MP/mrc_default.css?v=0.74" mrcfile="150" rel="stylesheet" type="text/css"/>
#   <link href="/mrcjava/mrcclasses/jquery.custom.css" rel="stylesheet" type="text/css"/>
#   <!--[if !IE]>
# <link href="/mrcjava/mrcclasses/mrc-responsive.css" rel="stylesheet" />
# <![endif]-->
#   <!--[if IE 7]>
# <link href="/mrcjava/mrcclasses/font/css/font-awesome-ie7.css" rel="stylesheet" />
# <![endif]-->
#   <style type="text/css">
#    #sort_table_head a {pointer-events: none;}
#           #sort_table_head i {display: none;}
#       #sort_table_head [data-col="LASTNP"] a,
#       #sort_table_head [data-col="FIRSTP"] a {
#             pointer-events: initial;}
#       #sort_table_head [data-col="LASTNP"] i,
#       #sort_table_head [data-col="FIRSTP"] i {
#             display: initial;}
#           .viewCount {text-align: center;}
#           .filterOptions.mobileOnly {display: none;}
#           /*@media screen and (min-width: 761px) {
#             body > div.ui-dialog {
#               top: 50% !important;
#               transform: translateY(-50%);
#             }
#           }*/
#   </style>
#   <script src="/mrcjava/mrcclasses/mpowerapps.js" type="text/javascript">
#   </script>
#   <script mrcfile="mobileSortAndFilter.js" src="/mrcjava/mrcclasses/SH01_MP/js/mobileSortAndFilter.js" type="text/javascript">
#   </script>
#   <script mrcfile="websiteNotification.js" src="/mrcjava/mrcclasses/SH01_MP/js/websiteNotification.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var s1 = new Image().src = '/mrcjava/image/ascg.gif',
#           s0 = new Image().src = '/mrcjava/image/descg.gif';
#   </script>
#  </head>
#  <body>
#   <!-- Begin mrc Header -->
#   <div class="page-wrap">
#    <!-- -->
#    <!-- Begin mrc Default Desktop Header -->
#    <!-- Begin JavaScript Required Message -->
#    <noscript>
#     <div class="warning noJS">
#      The Boone County website
#      <strong>
#       requires
#      </strong>
#      JavaScript to function correctly. Please enable JavaScript in your browser.
#     </div>
#    </noscript>
#    <!-- End JavaScript Required Message -->
#    <!-- Begin Image Bar -->
#    <div class="pageHeader DepartmentHeader container">
#     <div class="DepartmentHeaderGraphic">
#      <img alt="Boone County Sheriff's Badge" src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg"/>
#     </div>
#     <div class="DepartmentHeaderInfo">
#      <div class="DepartmentHeaderTitle">
#       Boone County Sheriff's Department
#      </div>
#      <div class="container">
#       <div class="DepartmentHeaderAddress">
#        Boone County Sheriff's Department
#        <br/>
#        2121 County Dr.
#        <br/>
#        Columbia, MO 65202
#       </div>
#       <div class="DepartmentHeaderNumbers">
#        Office (573) 875-1111
#        <br/>
#        Fax (573) 874-8953
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- End Image Bar -->
#    <!-- Begin Link Bar -->
#    <div class="container noPrint" id="headerMenu">
#     <ul>
#      <li>
#       <a href="http://www.boonecountymo.org/sheriff">
#        Home
#       </a>
#      </li>
#      <li class="mainMenu">
#       <a href="/mrcjava/servlet/SH01_MP.I00040s">
#        Menu
#       </a>
#      </li>
#      <li>
#       <a class="" href="/mrcjava/servlet/SH01_MP.I00030s" target="_new">
#        Help
#       </a>
#      </li>
#      <!--<li class="options">
#       <a href="#"  onclick="viewOptions();">
#         Options
#       </a>
#     </li>-->
#     </ul>
#    </div>
#    <!-- End Link Bar -->
#    <!-- End mrc Default Desktop Header -->
#    <!-- Begin BC Custom Mobile Header-->
#    <div class="fixedHeader">
#     <div class="fixedHeaderButton bcSealButton">
#      <a class="transparent" href="http://www.boonecountymo.org/Sheriff/">
#       <img alt="Boone County Sheriff's Badge" class="bcSeal shBadge" src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg"/>
#      </a>
#     </div>
#     <div class="fixedHeaderButton menuButton">
#      <!--Link to custom menu page-->
#      <a class="transparent" href="/mrcjava/servlet/SH01_MP.I00040s">
#       Menu
#      </a>
#     </div>
#     <!--<div class="options fixedHeaderButton optionsButton">
#   <a class="transparent" href="#" id="options" onclick="viewOptions();">
#     <i class="fa fa-2x fa-gear optionsIcon">&nbsp;</i>
#   </a>
#   </div>-->
#     <div class="fixedHeaderButton helpButton">
#      <!--Link to help page-->
#      <a class="transparent" href="/mrcjava/servlet/SH01_MP.I00030s">
#       Help
#      </a>
#     </div>
#     <div class="fixedHeaderButton optionsButton hiddenButton">
#     </div>
#     <div class="headerTitle">
#      <!--Link to department home page-->
#      <a class="transparent" href="http://www.boonecountymo.org/Sheriff/">
#       Boone County Sheriff's Department
#      </a>
#     </div>
#    </div>
#    <!-- End BC Custom Mobile Header-->
#    <script type="text/javascript">
#     if (window.location.hostname == "s10ccd5c.boonecountymo.org") {
#    jQuery('a[href="/mrcjava/servlet/BC00_MP.mrcMenu"]').attr(
#      'href',
#      '/mrcjava/servlet/MRCTEST.mrcMenu'
#    );
#  }
#    </script>
#    <!-- -->
#    <!-- End mrc Header -->
#    <!-- Begin Title Bar -->
#    <div class="title">
#     Current Detainees of Boone County Jail
#    </div>
#    <!-- End Title Bar -->
#    <!-- -->
#    <div id="applicationOptions" style="padding: 10px; DISPLAY: none; FONT: 8pt verdana;">
#     <table cellpadding="0" cellspacing="0" class="collapse BCSDTable shadow">
#      <tbody>
#       <tr class="even">
#        <!-- -->
#        <td class="two" style="border-bottom:1px solid #000" valign="top">
#         <table border="0" cellpadding="1" cellspacing="1" class="BCSDTable" width="350">
#          <tbody>
#           <tr>
#            <th>
#             Saved Searches
#            </th>
#           </tr>
#           <tr>
#            <td align="left" style="PADDING-LEFT: 10px; PADDING-RIGHT: 10px">
#             <div id="search_input">
#              <br/>
#              <font size="2">
#               <strong>
#                Name Current Search:
#               </strong>
#               <br/>
#              </font>
#              <input id="dialogViewName" name="dialogViewName" size="35"/>
#              <img alt="" height="19" onclick="saveView();" src="/mrcjava/image/view_save.png" style="CURSOR: pointer" width="20"/>
#              <br/>
#             </div>
#             <br/>
#             <font size="2">
#              <strong>
#               Execute Saved Search:
#              </strong>
#             </font>
#             <br/>
#             <table border="0" cellpadding="1" cellspacing="1" mrc_app="SH01_MP.I00290s">
#              <tbody>
#              </tbody>
#             </table>
#             <br/>
#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </td>
#        <!-- -->
#        <td class="two" style="border-bottom:1px solid #000" valign="top">
#         <table border="0" cellpadding="1" cellspacing="1" class="BCSDTable" width="200">
#          <tbody>
#           <tr>
#            <th>
#             Browser Mode
#            </th>
#           </tr>
#           <tr>
#            <td align="left" style="PADDING-LEFT: 10px; PADDING-RIGHT: 10px">
#             <br/>
#             <font size="2">
#              <strong>
#               Select Browsing Mode:
#              </strong>
#             </font>
#             <br/>
#             <br/>
#             <table border="0" cellpadding="1" cellspacing="1" id="device_select_table">
#              <tbody>
#               <tr>
#                <td>
#                 <img src="/mrcjava/image/check.png"/>
#                </td>
#                <td>
#                 <font size="2">
#                  <a class="standard" href="#" onclick="switchDevice('pc')">
#                   PC
#                  </a>
#                 </font>
#                </td>
#               </tr>
#               <tr>
#                <td>
#                </td>
#                <td>
#                 <font size="2">
#                  <a class="standard" href="#" onclick="switchDevice('mob')">
#                   Mobile
#                  </a>
#                 </font>
#                </td>
#               </tr>
#              </tbody>
#             </table>
#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </td>
#       </tr>
#      </tbody>
#     </table>
#    </div>
#    <!-- -->
#    <div class="ajax_content table-wrapper box-shadow" id="mrcMainContent">
#     <form action="SH01_MP.I00290s" autocomplete="off" data-app_type="I" id="FORM_I00290" method="post" name="FORM_I00290">
#      <!-- Begin Run Time Message -->
#      <div class="errortext1">
#      </div>
#      <!-- End Run Time Message -->
#      <div class="searchWrapper">
#       <div class="search card">
#        <div class="card-title">
#         Search By Name
#        </div>
#        <div class="card-block">
#         <div>
#          <label>
#           Last Name:
#          </label>
#          <select class="mrcselect relation" id="F_C_LI_LASTNP" name="rls_LASTNP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option selected="selected" title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_LASTNP" name="val_LASTNP" size="32" title="val_LASTNP" type="text" value=""/>
#         </div>
#         <div>
#          <label>
#           First Name:
#          </label>
#          <select class="mrcselect relation" id="F_C_LI_FIRSTP" name="rls_FIRSTP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option selected="selected" title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_FIRSTP" name="val_FIRSTP" size="32" title="val_FIRSTP" type="text" value=""/>
#         </div>
#         <div>
#          <button class="btn btn-primary" name="btn_search" type="submit">
#           <i class="fa fa-large fa-search">
#           </i>
#           Search
#          </button>
#          <button class="btn btn-default" name="btn_reset" type="reset">
#           <i class="fa fa-large fa-repeat">
#           </i>
#           Reset
#          </button>
#          <a class="btn btn-default" href="SH01_MP.R00250s?run=2">
#           <i class="fa fa-large fa-file-excel-o">
#           </i>
#           Export Detainees &amp; Charges to Excel
#          </a>
#         </div>
#        </div>
#        <div class="card-block">
#         <strong>
#          Run Date: 08/04/18
#         </strong>
#        </div>
#       </div>
#      </div>
#      <!-- Begin Data Table -->
#      <script>
#       jQuery(document).ready(function(){         var greynames=new Array("s1LASTNP","s1FIRSTP","s1MIDDLP","s1PERKEP"); setSortImage2(greynames,'FORM_I00290'); });
#      </script>
#      <table cellspacing="0" class="collapse data-table shadow responsive">
#       <thead>
#        <tr class="tr-paging">
#         <th class="th_left paging_row" colspan="93">
#          <!-- -->
#          <!--<button class="btn btn-primary" name="btn_search" type="submit"><i class="fa fa-large fa-filter">&nbsp;</i> Filter</button>-->
#          218 Total Items  |  Page Size
#          <input class="mrcinput" name="max_rows" size="3" title="max_rowsp" type="text" value="50"/>
#          <!-- -->
#          <!--
# <img alt class="to-excel-img" src="/mrcjava/image/format_excel.png" title="Microsoft Excel format" /> &nbsp; -->
#          <!-- -->
#          <div class="pagination pagination-right fixed-pagination">
#           <ul>
#            <li>
#             <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#              <i class="fa fa-angle-double-left fa-large">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#              <i class="fa fa-angle-left fa-large">
#              </i>
#             </a>
#            </li>
#            <li class="disabled">
#             <a href="#">
#              Page 1 of 5
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#              <i class="fa fa-angle-right fa-large">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#              <i class="fa fa-angle-double-right fa-large">
#              </i>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </th>
#        </tr>
#        <!--BEGIN_SORT_TABLE_HEADER-->
#        <tr class="table-header" id="sort_table_head">
#         <th data-col="LASTNP">
#          <a class="sort-col" data-field="LASTNP" href="javascript:void(0)">
#           Last Name
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th data-col="FIRSTP">
#          <a class="sort-col" data-field="FIRSTP" href="javascript:void(0)">
#           First Name
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="MIDDLP">
#          <a class="sort-col" data-field="MIDDLP" href="javascript:void(0)">
#           Middle Name
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="SEXCOP">
#          <a class="sort-col" data-field="SEXCOP" href="javascript:void(0)">
#           Sex
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="RACECP">
#          <a class="sort-col" data-field="RACECP" href="javascript:void(0)">
#           Race
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="AGEBEP">
#          <a class="sort-col" data-field="AGEBEP" href="javascript:void(0)">
#           Age
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="CITYMP">
#          <a class="sort-col" data-field="CITYMP" href="javascript:void(0)">
#           City
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile" data-col="STATEP">
#          <a class="sort-col" data-field="STATEP" href="javascript:void(0)">
#           State
#           <i class="fa fa-sort">
#           </i>
#          </a>
#         </th>
#         <th class="hideOnMobile">
#         </th>
#        </tr>
#        <!--END_SORT_TABLE_HEADER-->
#        <!--BEGIN_ADVANCED_SEARCH-->
#        <!-- -->
#        <tr id="search_table_head" style="display: none;">
#         <th align="center">
#          <a class="nav" href="/mrcjava/mrcclasses/filter_relationship_help.html" linkedtype="" target="_blank" title="Filter Relationship Help">
#           ?
#          </a>
#          <select class="mrcselect relation" id="F_C_LI_LASTNP" name="rls_LASTNP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_LASTNP" name="val_LASTNP" size="6" title="val_LASTNP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_FIRSTP" name="rls_FIRSTP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_FIRSTP" name="val_FIRSTP" size="6" title="val_FIRSTP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_MIDDLP" name="rls_MIDDLP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_MIDDLP" name="val_MIDDLP" size="6" title="val_MIDDLP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_SEXCOP" name="rls_SEXCOP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_SEXCOP" name="val_SEXCOP" size="6" title="val_SEXCOP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_RACECP" name="rls_RACECP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_RACECP" name="val_RACECP" size="6" title="val_RACECP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_AGEBEP" name="rls_AGEBEP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_AGEBEP" name="val_AGEBEP" size="6" title="val_AGEBEP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_CITYMP" name="rls_CITYMP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_CITYMP" name="val_CITYMP" size="6" title="val_CITYMP" type="text" value=""/>
#         </th>
#         <th align="center">
#          <select class="mrcselect relation" id="F_C_LI_STATEP" name="rls_STATEP">
#           <option title="Equal" value="EQ">
#            EQ
#           </option>
#           <option title="Not equal" value="NE">
#            NE
#           </option>
#           <option title="Greater than or equal" value="GE">
#            GE
#           </option>
#           <option title="Greater than" value="GT">
#            GT
#           </option>
#           <option title="Less than or equal" value="LE">
#            LE
#           </option>
#           <option title="Less than" value="LT">
#            LT
#           </option>
#           <option title="In the list" value="LS">
#            LS
#           </option>
#           <option title="Not in the list" value="NS">
#            NS
#           </option>
#           <option title="In the range" value="RG">
#            RG
#           </option>
#           <option title="Not in the range" value="NR">
#            NR
#           </option>
#           <option title="Contains" value="CT">
#            CT
#           </option>
#           <option title="Does not Contain" value="NC">
#            NC
#           </option>
#           <option title="Contains all" value="CA">
#            CA
#           </option>
#           <option title="Contains any" value="CO">
#            CO
#           </option>
#           <option title="Starts with" value="SW">
#            SW
#           </option>
#           <option title="Does not Start with" value="NW">
#            NW
#           </option>
#          </select>
#          <input class="mrcinput" id="val_STATEP" name="val_STATEP" size="6" title="val_STATEP" type="text" value=""/>
#         </th>
#         <th align="center">
#         </th>
#        </tr>
#        <!-- -->
#       </thead>
#       <!--END_ADVANCED_SEARCH-->
#       <tbody class="stripe" id="mrc_main_table">
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          ACTON
#         </td>
#         <td class="one td_left" data-th="First Name">
#          ANTHONY
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          SEAN
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          26
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66619&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          AKERS
#         </td>
#         <td class="two td_left" data-th="First Name">
#          SYDNEY
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          RAE
#         </td>
#         <td class="two td_left" data-th="Sex">
#          F
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          21
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76028&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          ALEXANDER
#         </td>
#         <td class="one td_left" data-th="First Name">
#          BENJAMIN
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          FRANKLIN
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          23
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74927&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          ANDERSON
#         </td>
#         <td class="two td_left" data-th="First Name">
#          ANTHONY
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          CURTIS
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          26
#         </td>
#         <td class="two td_left" data-th="City">
#          NEVADA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=73709&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          ARMSTRONG
#         </td>
#         <td class="one td_left" data-th="First Name">
#          ANTIONE
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          LAMONT
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          18
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79483&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          AULL
#         </td>
#         <td class="two td_left" data-th="First Name">
#          JONATHAN
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          MORGAN
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          37
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=29434&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BAKER
#         </td>
#         <td class="one td_left" data-th="First Name">
#          CHRISTOPHER
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          ALAN
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          28
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=59254&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BAKER
#         </td>
#         <td class="two td_left" data-th="First Name">
#          MICHAEL
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          COREY
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          27
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=65703&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BANNERMAN
#         </td>
#         <td class="one td_left" data-th="First Name">
#          KRYSTAL
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          MARIE
#         </td>
#         <td class="one td_left" data-th="Sex">
#          F
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          30
#         </td>
#         <td class="one td_left" data-th="City">
#          CENTRALIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78997&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BARNES
#         </td>
#         <td class="two td_left" data-th="First Name">
#          DARIUS
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          JOSHUA
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          22
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74492&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BARTZ-OWENS
#         </td>
#         <td class="one td_left" data-th="First Name">
#          ASHLEY
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          SUE
#         </td>
#         <td class="one td_left" data-th="Sex">
#          F
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          32
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76757&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BECK
#         </td>
#         <td class="two td_left" data-th="First Name">
#          JOSHUA
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          ALEX
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          25
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81210&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BENEDETTI
#         </td>
#         <td class="one td_left" data-th="First Name">
#          FRANK
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          DOMINICK
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          29
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79913&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BETTS
#         </td>
#         <td class="two td_left" data-th="First Name">
#          VITA
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          LAMETA
#         </td>
#         <td class="two td_left" data-th="Sex">
#          F
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          45
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=42055&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BLAIR
#         </td>
#         <td class="one td_left" data-th="First Name">
#          CONNIE
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          MARIE
#         </td>
#         <td class="one td_left" data-th="Sex">
#          F
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          36
#         </td>
#         <td class="one td_left" data-th="City">
#          COLDWATER
#         </td>
#         <td class="one td_left" data-th="State">
#          MS
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=55579&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          BLEVINS
#         </td>
#         <td class="two td_left" data-th="First Name">
#          JESSE
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          RAY
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          29
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68185&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          BOND
#         </td>
#         <td class="one td_left" data-th="First Name">
#          SOPHIA
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          LYNN
#         </td>
#         <td class="one td_left" data-th="Sex">
#          F
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          24
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
# ...
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          31
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76524&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          CURETON
#         </td>
#         <td class="one td_left" data-th="First Name">
#          ERIC
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          WAYNE
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          B
#         </td>
#         <td class="one td_right" data-th="Age">
#          51
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=6090&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          DAVID
#         </td>
#         <td class="two td_left" data-th="First Name">
#          JACK
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          ALLEN
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          25
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=64058&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          DAVIS
#         </td>
#         <td class="one td_left" data-th="First Name">
#          RAQUEL
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          ELIZABETH
#         </td>
#         <td class="one td_left" data-th="Sex">
#          F
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          29
#         </td>
#         <td class="one td_left" data-th="City">
#          HALLSVILLE
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77173&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          DAVIS
#         </td>
#         <td class="two td_left" data-th="First Name">
#          RONNELL
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          B
#         </td>
#         <td class="two td_right" data-th="Age">
#          21
#         </td>
#         <td class="two td_left" data-th="City">
#          KANSAS CITY
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80782&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          DEACON
#         </td>
#         <td class="one td_left" data-th="First Name">
#          DUSTIN
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          ODALE
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          W
#         </td>
#         <td class="one td_right" data-th="Age">
#          26
#         </td>
#         <td class="one td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="one td_left" data-th="State">
#          MO
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56406&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          DEFRANCESCO
#         </td>
#         <td class="two td_left" data-th="First Name">
#          FRANK
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          ANGELO
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          32
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81469&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="odd">
#         <td class="one td_left" data-th="Last Name">
#          DELOSDIOS
#         </td>
#         <td class="one td_left" data-th="First Name">
#          JOSE
#         </td>
#         <td class="one td_left" data-th="Middle Name">
#          MIGUEL
#         </td>
#         <td class="one td_left" data-th="Sex">
#          M
#         </td>
#         <td class="one td_left" data-th="Race">
#          H
#         </td>
#         <td class="one td_right" data-th="Age">
#          38
#         </td>
#         <td class="one td_left" data-th="City">
#          BRONX CITY
#         </td>
#         <td class="one td_left" data-th="State">
#          NY
#         </td>
#         <td class="one td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=75665&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="even">
#         <td class="two td_left" data-th="Last Name">
#          DEVINE
#         </td>
#         <td class="two td_left" data-th="First Name">
#          STEVEN
#         </td>
#         <td class="two td_left" data-th="Middle Name">
#          PATRICK
#         </td>
#         <td class="two td_left" data-th="Sex">
#          M
#         </td>
#         <td class="two td_left" data-th="Race">
#          W
#         </td>
#         <td class="two td_right" data-th="Age">
#          42
#         </td>
#         <td class="two td_left" data-th="City">
#          COLUMBIA
#         </td>
#         <td class="two td_left" data-th="State">
#          MO
#         </td>
#         <td class="two td_left" data-th="">
#          <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80870&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#           <i class="fa fa-large fa-fw fa-list-alt">
#           </i>
#           Details
#          </a>
#         </td>
#        </tr>
#        <!-- -->
#        <tr class="tr-paging">
#         <th class="th_left paging_row bottomPaging" colspan="93">
#          Detainee Count: 218
#          <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
#           <ul>
#            <li>
#             <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#              <i class="fa fa-angle-double-left fa-large">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#              <i class="fa fa-angle-left fa-large">
#              </i>
#             </a>
#            </li>
#            <li class="disabled">
#             <a href="#">
#              Page 1 of 5
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#              <i class="fa fa-angle-right fa-large">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#              <i class="fa fa-angle-double-right fa-large">
#              </i>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </th>
#        </tr>
#       </tbody>
#      </table>
#      <!-- End data table -->
#      <div class="viewCount">
#       <strong>
#        This page has been viewed
#        <title>
#        </title>
#        2,408,240
#
#  times since 1/3/06
#       </strong>
#      </div>
#      <!-- End Background Table -->
#      <div class="back" contenteditable="false" id="hiddenfields">
#       <input name="slnk" type="hidden" value="0"/>
#       <input name="sort_col" type="hidden" value="LASTNP"/>
#       <input name="sort_typ" type="hidden" value="1"/>
#       <input name="cur_sort_col" type="hidden" value=""/>
#       <input name="reorder" type="hidden" value=""/>
#       <input name="pageName" type="hidden" value=""/>
#       <input name="preview" type="hidden" value="0"/>
#       <input name="debug" type="hidden" value="0"/>
#       <input name="pageNum" type="hidden" value="1"/>
#       <input name="total_pages" type="hidden" value="5"/>
#       <input name="total_rows" type="hidden" value="218"/>
#       <input id="ajax_form" name="ajax_form" type="hidden" value="0"/>
#       <input name="auto_refresh" type="hidden" value="0"/>
#       <input id="toexcel" name="excel" type="hidden" value="0"/>
#       <input id="use_udview" name="use_udview" type="hidden" value="0"/>
#      </div>
#     </form>
#    </div>
#    <!-- Begin mrc Footer -->
#    <!-- Begin Boone County Default Footer -->
#    <!-- Begin Bottom Lines of Text -->
#    <div class="foottext">
#     <div class="footerMenuLinks noPrint">
#      <a href="http://showmeboone.com" title="www.showmeboone.com">
#       Home
#      </a>
#      |
#      <a href="http://showmeboone.com/home/accessibility.asp" title="Accessibility">
#       Accessibility
#      </a>
#      |
#      <a href="http://showmeboone.com/Home/CountyOfficials.asp" title="County Officials">
#       County Officials
#      </a>
#      |
#      <a href="http://showmeboone.com/Home/ContactUs.asp" title="Hours &amp; Location">
#       Hours &amp; Location
#      </a>
#      |
#      <a href="http://showmeboone.com/Home/sitemap.asp" title="Site Map">
#       Site Map
#      </a>
#      |
#      <a href="http://showmeboone.com/redirect.asp?url=http://oseda.missouri.edu/cgi-bin/countypage?29019" title="County Fact Sheet">
#       County Fact Sheet
#      </a>
#      <p>
#      </p>
#      <div class="footerMenuLinksRow">
#       <a href="http://showmeboone.com/ASSESSOR/" target="_top" title="Assessor">
#        Assessor
#       </a>
#       |
#       <a href="http://showmeboone.com/AUDITOR/" target="_top" title="Auditor">
#        Auditor
#       </a>
#       |
#       <a href="http://showmeboone.com/CLERK/" target="_top" title="County Clerk">
#        County Clerk
#       </a>
#       |
#       <a href="http://showmeboone.com/COLLECTOR/" target="_top" title="Collector">
#        Collector
#       </a>
#       |
#       <a href="http://showmeboone.com/COMMISSION/" target="_top" title="Commission">
#        Commission
#       </a>
#       |
#       <a href="http://showmeboone.com/HR/" target="_top" title="Human Resources">
#        Human Resources
#       </a>
#       |
#       <a href="http://showmeboone.com/GIS/" target="_top" title="GIS">
#        GIS
#       </a>
#      </div>
#      <div class="footerMenuLinksRow">
#       <a href="https://showmeboone.com/BCJC/" target="_top" title="Joint Communications">
#        Joint Communications
#       </a>
#       |
#       <a href="http://showmeboone.com/PA/" target="_top" title="Prosecuting Attorney">
#        Prosecuting Attorney
#       </a>
#       |
#       <a href="http://showmeboone.com/publicworks/" target="_top" title="Public Works">
#        Public Works
#       </a>
#       |
#       <a href="http://showmeboone.com/PURCHASING/" target="_top" title="Purchasing">
#        Purchasing
#       </a>
#       |
#       <a href="http://showmeboone.com/PUBLICADMIN/" target="_top" title="Public Administrator">
#        Public Administrator
#       </a>
#      </div>
#      <div class="footerMenuLinksRow">
#       <a href="http://showmeboone.com/RECORDER/" target="_top" title="Recorder of Deeds">
#        Recorder of Deeds
#       </a>
#       |
#       <a href="http://showmeboone.com/ResourceManagement/" target="_top" title="Resource Management">
#        Resource Management
#       </a>
#       |
#       <a href="http://www.boonecountymo.org/sheriff/" target="_top" title="Sheriff">
#        Sheriff
#       </a>
#       |
#       <a href="http://showmeboone.com/TREASURER/" target="_top" title="Treasurer">
#        Treasurer
#       </a>
#      </div>
#     </div>
#     <p class="noPrint footerListservLink" style="text-align:center; font-weight: bold;">
#      <a class="email" href="https://www.showmeboone.com/countylistserv.asp" target="_top" title="Subscribe to the Boone County News email list">
#       Subscribe
#      </a>
#      to the Boone County News email list.
#     </p>
#     Copyright © 2018 Boone County, Missouri.  All rights reserved.
#     <br/>
#     This Web application was developed by
#     <a href="http://www.boonecountymo.org">
#      Boone County
#     </a>
#     .
#    </div>
#    <!-- End Bottom Lines of Text -->
#    <!-- End Boone County Default Footer -->
#   </div>
#   <!-- End mrc Footer -->
#   <!-- do not delete this comment.
# -->
#   <!-- Template date: 2014-08-29 -->
#  </body>
# </html>
# C:\Users\karls\Anaconda2\envs\py36\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\karls\Anaconda2\envs\py36\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# You should see the page’s HTML again, but in a prettier format this time.
#
# **Next** we take all the detective work we did with the page’s HTML above and convert it into a simple, direct command that will **instruct BeautifulSoup on how to extract only the table we’re after.**

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'}) # NEW CODE
print (table.prettify())
# Out:
# <tbody class="stripe" id="mrc_main_table">
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    ACTON
#   </td>
#   <td class="one td_left" data-th="First Name">
#    ANTHONY
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    SEAN
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    26
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66619&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    AKERS
#   </td>
#   <td class="two td_left" data-th="First Name">
#    SYDNEY
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    RAE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    F
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    21
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76028&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    ALEXANDER
#   </td>
#   <td class="one td_left" data-th="First Name">
#    BENJAMIN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    FRANKLIN
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    23
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74927&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    ANDERSON
#   </td>
#   <td class="two td_left" data-th="First Name">
#    ANTHONY
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    CURTIS
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    26
#   </td>
#   <td class="two td_left" data-th="City">
#    NEVADA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=73709&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    ARMSTRONG
#   </td>
#   <td class="one td_left" data-th="First Name">
#    ANTIONE
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    LAMONT
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    18
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79483&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    AULL
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JONATHAN
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    MORGAN
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    37
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=29434&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BAKER
#   </td>
#   <td class="one td_left" data-th="First Name">
#    CHRISTOPHER
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    ALAN
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    28
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=59254&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BAKER
#   </td>
#   <td class="two td_left" data-th="First Name">
#    MICHAEL
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    COREY
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    27
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=65703&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BANNERMAN
#   </td>
#   <td class="one td_left" data-th="First Name">
#    KRYSTAL
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    MARIE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    30
#   </td>
#   <td class="one td_left" data-th="City">
#    CENTRALIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78997&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BARNES
#   </td>
#   <td class="two td_left" data-th="First Name">
#    DARIUS
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    JOSHUA
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    22
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74492&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BARTZ-OWENS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    ASHLEY
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    SUE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    32
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76757&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BECK
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JOSHUA
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    ALEX
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    25
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81210&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BENEDETTI
#   </td>
#   <td class="one td_left" data-th="First Name">
#    FRANK
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    DOMINICK
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    29
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79913&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BETTS
#   </td>
#   <td class="two td_left" data-th="First Name">
#    VITA
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    LAMETA
#   </td>
#   <td class="two td_left" data-th="Sex">
#    F
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    45
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=42055&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BLAIR
#   </td>
#   <td class="one td_left" data-th="First Name">
#    CONNIE
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    MARIE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    36
#   </td>
#   <td class="one td_left" data-th="City">
#    COLDWATER
#   </td>
#   <td class="one td_left" data-th="State">
#    MS
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=55579&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BLEVINS
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JESSE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    RAY
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    29
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68185&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BOND
#   </td>
#   <td class="one td_left" data-th="First Name">
#    SOPHIA
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    LYNN
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    24
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=67252&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BOWEN
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JAMIE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    ROGER
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    38
#   </td>
#   <td class="two td_left" data-th="City">
#    HIGBEE
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=35135&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BRADLEY
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JAMIE
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    MICHELLE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    33
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=44762&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BRADSHAW
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JOSEPH
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    LEE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    42
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=12105&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BRESEE
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JAMES
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    ANTONIO
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    36
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66101&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BRILL
#   </td>
#   <td class="two td_left" data-th="First Name">
#    BRANDON
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    NICHOLAS
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    27
#   </td>
#   <td class="two td_left" data-th="City">
#    CLARK
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60089&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BROWN
#   </td>
#   <td class="one td_left" data-th="First Name">
#    AARON
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    MICHAEL
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    37
#   </td>
#   <td class="one td_left" data-th="City">
#    AKENY
#   </td>
#   <td class="one td_left" data-th="State">
#    IA
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79340&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BROWN
#   </td>
#   <td class="two td_left" data-th="First Name">
#    BARRY
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    RONELL
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    31
#   </td>
#   <td class="two td_left" data-th="City">
#    FLORISSANT
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80297&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BROWN
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JEREMIAH
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    EZEKIEL
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    33
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=37899&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BRYANT
#   </td>
#   <td class="two td_left" data-th="First Name">
#    KYLE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    JAMES
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    28
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79791&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BUCKNER
#   </td>
#   <td class="one td_left" data-th="First Name">
#    KEVIN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    MAURICE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    18
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77661&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    BUTLER
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JEMELL
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    DUPRUE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    22
#   </td>
#   <td class="two td_left" data-th="City">
#    JEFFERSON CITY
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72107&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    BUTLER
#   </td>
#   <td class="one td_left" data-th="First Name">
#    KEIRAN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    DONOVAN
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    19
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=75765&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CALVERT
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JOHN
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    RAY
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    36
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=33863&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CAMPBELL
#   </td>
#   <td class="one td_left" data-th="First Name">
#    OTIS
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    LEE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    22
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72090&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CAMPBELL
#   </td>
#   <td class="two td_left" data-th="First Name">
#    WILLEM
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    DAKOTAH
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    24
#   </td>
#   <td class="two td_left" data-th="City">
#    STOVER
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=75233&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CANFIELD
#   </td>
#   <td class="one td_left" data-th="First Name">
#    NATHAN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    EDWARD
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    36
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79636&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CARTER
#   </td>
#   <td class="two td_left" data-th="First Name">
#    DARIAN
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    MAURICE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    25
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56088&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CAUDLE
#   </td>
#   <td class="one td_left" data-th="First Name">
#    LINDA
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    JOYCE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    56
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=8935&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CELEDON-FLOCK
#   </td>
#   <td class="two td_left" data-th="First Name">
#    ARMANDO
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    AGUIRRE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    30
#   </td>
#   <td class="two td_left" data-th="City">
#    RIALTO
#   </td>
#   <td class="two td_left" data-th="State">
#    CA
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81223&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CHEATOM
#   </td>
#   <td class="one td_left" data-th="First Name">
#    DARIEN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    CAPRI
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    24
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=61765&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CHILTON
#   </td>
#   <td class="two td_left" data-th="First Name">
#    CHRISTIAN
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    TYLER
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    22
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81260&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CHRISTMAS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JUSTIN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    LYNN
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    42
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24788&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    COMMANDER
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JAVANTE
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    BRUCE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    23
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68940&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CROY
#   </td>
#   <td class="one td_left" data-th="First Name">
#    MARANDA
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    LEE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    32
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=38647&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    CRUMP
#   </td>
#   <td class="two td_left" data-th="First Name">
#    VICTOR
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    EUGENE
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    31
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76524&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    CURETON
#   </td>
#   <td class="one td_left" data-th="First Name">
#    ERIC
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    WAYNE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    B
#   </td>
#   <td class="one td_right" data-th="Age">
#    51
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=6090&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    DAVID
#   </td>
#   <td class="two td_left" data-th="First Name">
#    JACK
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    ALLEN
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    25
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=64058&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    DAVIS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    RAQUEL
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    ELIZABETH
#   </td>
#   <td class="one td_left" data-th="Sex">
#    F
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    29
#   </td>
#   <td class="one td_left" data-th="City">
#    HALLSVILLE
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77173&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    DAVIS
#   </td>
#   <td class="two td_left" data-th="First Name">
#    RONNELL
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    B
#   </td>
#   <td class="two td_right" data-th="Age">
#    21
#   </td>
#   <td class="two td_left" data-th="City">
#    KANSAS CITY
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80782&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    DEACON
#   </td>
#   <td class="one td_left" data-th="First Name">
#    DUSTIN
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    ODALE
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    26
#   </td>
#   <td class="one td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56406&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    DEFRANCESCO
#   </td>
#   <td class="two td_left" data-th="First Name">
#    FRANK
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    ANGELO
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    32
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81469&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    DELOSDIOS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JOSE
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    MIGUEL
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    H
#   </td>
#   <td class="one td_right" data-th="Age">
#    38
#   </td>
#   <td class="one td_left" data-th="City">
#    BRONX CITY
#   </td>
#   <td class="one td_left" data-th="State">
#    NY
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=75665&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
#   <td class="two td_left" data-th="Last Name">
#    DEVINE
#   </td>
#   <td class="two td_left" data-th="First Name">
#    STEVEN
#   </td>
#   <td class="two td_left" data-th="Middle Name">
#    PATRICK
#   </td>
#   <td class="two td_left" data-th="Sex">
#    M
#   </td>
#   <td class="two td_left" data-th="Race">
#    W
#   </td>
#   <td class="two td_right" data-th="Age">
#    42
#   </td>
#   <td class="two td_left" data-th="City">
#    COLUMBIA
#   </td>
#   <td class="two td_left" data-th="State">
#    MO
#   </td>
#   <td class="two td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80870&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="tr-paging">
#   <th class="th_left paging_row bottomPaging" colspan="93">
#    Detainee Count: 218
#    <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
#     <ul>
#      <li>
#       <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#        <i class="fa fa-angle-double-left fa-large">
#        </i>
#       </a>
#      </li>
#      <li>
#       <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#        <i class="fa fa-angle-left fa-large">
#        </i>
#       </a>
#      </li>
#      <li class="disabled">
#       <a href="#">
#        Page 1 of 5
#       </a>
#      </li>
#      <li>
#       <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#        <i class="fa fa-angle-right fa-large">
#        </i>
#       </a>
#      </li>
#      <li>
#       <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#        <i class="fa fa-angle-double-right fa-large">
#        </i>
#       </a>
#      </li>
#     </ul>
#    </div>
#   </th>
#  </tr>
# </tbody>
# C:\Users\karls\Anaconda2\envs\py36\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\karls\Anaconda2\envs\py36\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# This time it only prints out the table we’re after, which was selected by instructing BeautifulSoup to return only those *&lt;table&gt;* tags with resultsTable as their class attribute.
#
# **Convert the rows in the table into a list**, which we can then loop through and grab all the data out of.
#
# **BeautifulSoup** gets us going by allowing us to dig down into our table and **return a list of rows, which are created in HTML using *&lt;tr&gt;* tags** inside the table.

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

for row in table.findAll('tr'):  # NEW CODE
    print (row.prettify())
# Out:
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ACTON
#  </td>
#  <td class="one td_left" data-th="First Name">
#   ANTHONY
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   SEAN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   26
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66619&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   AKERS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   SYDNEY
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   RAE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   F
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   21
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76028&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ALEXANDER
#  </td>
#  <td class="one td_left" data-th="First Name">
#   BENJAMIN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   FRANKLIN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   23
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74927&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   ANDERSON
#  </td>
#  <td class="two td_left" data-th="First Name">
#   ANTHONY
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   CURTIS
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   26
#  </td>
#  <td class="two td_left" data-th="City">
#   NEVADA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=73709&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ARMSTRONG
#  </td>
#  <td class="one td_left" data-th="First Name">
#   ANTIONE
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LAMONT
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   18
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79483&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   AULL
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JONATHAN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   MORGAN
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   37
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=29434&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BAKER
#  </td>
#  <td class="one td_left" data-th="First Name">
#   CHRISTOPHER
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   ALAN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   28
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=59254&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BAKER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   MICHAEL
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   COREY
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   27
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=65703&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BANNERMAN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   KRYSTAL
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MARIE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   30
#  </td>
#  <td class="one td_left" data-th="City">
#   CENTRALIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78997&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BARNES
#  </td>
#  <td class="two td_left" data-th="First Name">
#   DARIUS
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   JOSHUA
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   22
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=74492&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BARTZ-OWENS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   ASHLEY
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   SUE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   32
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76757&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BECK
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JOSHUA
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   ALEX
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   25
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81210&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BENEDETTI
#  </td>
#  <td class="one td_left" data-th="First Name">
#   FRANK
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   DOMINICK
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   29
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79913&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BETTS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   VITA
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   LAMETA
#  </td>
#  <td class="two td_left" data-th="Sex">
#   F
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   45
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=42055&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BLAIR
#  </td>
#  <td class="one td_left" data-th="First Name">
#   CONNIE
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MARIE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   36
#  </td>
#  <td class="one td_left" data-th="City">
#   COLDWATER
#  </td>
#  <td class="one td_left" data-th="State">
#   MS
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=55579&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BLEVINS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JESSE
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   RAY
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   29
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68185&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BOND
#  </td>
#  <td class="one td_left" data-th="First Name">
#   SOPHIA
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LYNN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   24
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=67252&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BOWEN
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JAMIE
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   ROGER
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   38
#  </td>
#  <td class="two td_left" data-th="City">
#   HIGBEE
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=35135&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BRADLEY
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JAMIE
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MICHELLE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   33
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=44762&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BRADSHAW
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JOSEPH
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   LEE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   42
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=12105&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BRESEE
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JAMES
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   ANTONIO
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   36
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66101&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BRILL
#  </td>
#  <td class="two td_left" data-th="First Name">
#   BRANDON
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   NICHOLAS
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   27
#  </td>
#  <td class="two td_left" data-th="City">
#   CLARK
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=60089&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BROWN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   AARON
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MICHAEL
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   37
#  </td>
#  <td class="one td_left" data-th="City">
#   AKENY
#  </td>
#  <td class="one td_left" data-th="State">
#   IA
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79340&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BROWN
#  </td>
#  <td class="two td_left" data-th="First Name">
#   BARRY
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   RONELL
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   31
#  </td>
#  <td class="two td_left" data-th="City">
#   FLORISSANT
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80297&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BROWN
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JEREMIAH
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   EZEKIEL
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   33
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=37899&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BRYANT
#  </td>
#  <td class="two td_left" data-th="First Name">
#   KYLE
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   JAMES
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   28
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79791&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BUCKNER
#  </td>
#  <td class="one td_left" data-th="First Name">
#   KEVIN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MAURICE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   18
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77661&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   BUTLER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JEMELL
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   DUPRUE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   22
#  </td>
#  <td class="two td_left" data-th="City">
#   JEFFERSON CITY
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72107&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   BUTLER
#  </td>
#  <td class="one td_left" data-th="First Name">
#   KEIRAN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   DONOVAN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   19
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=75765&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CALVERT
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JOHN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   RAY
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   36
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=33863&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CAMPBELL
#  </td>
#  <td class="one td_left" data-th="First Name">
#   OTIS
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LEE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   22
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=72090&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CAMPBELL
#  </td>
#  <td class="two td_left" data-th="First Name">
#   WILLEM
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   DAKOTAH
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   24
#  </td>
#  <td class="two td_left" data-th="City">
#   STOVER
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=75233&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CANFIELD
#  </td>
#  <td class="one td_left" data-th="First Name">
#   NATHAN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   EDWARD
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   36
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=79636&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CARTER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   DARIAN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   MAURICE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   25
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56088&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CAUDLE
#  </td>
#  <td class="one td_left" data-th="First Name">
#   LINDA
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   JOYCE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   56
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=8935&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CELEDON-FLOCK
#  </td>
#  <td class="two td_left" data-th="First Name">
#   ARMANDO
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   AGUIRRE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   30
#  </td>
#  <td class="two td_left" data-th="City">
#   RIALTO
#  </td>
#  <td class="two td_left" data-th="State">
#   CA
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81223&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CHEATOM
#  </td>
#  <td class="one td_left" data-th="First Name">
#   DARIEN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   CAPRI
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   24
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=61765&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CHILTON
#  </td>
#  <td class="two td_left" data-th="First Name">
#   CHRISTIAN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   TYLER
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   22
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81260&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CHRISTMAS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JUSTIN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LYNN
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   42
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=24788&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   COMMANDER
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JAVANTE
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   BRUCE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   23
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=68940&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CROY
#  </td>
#  <td class="one td_left" data-th="First Name">
#   MARANDA
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   LEE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   32
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=38647&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   CRUMP
#  </td>
#  <td class="two td_left" data-th="First Name">
#   VICTOR
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   EUGENE
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   31
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=76524&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   CURETON
#  </td>
#  <td class="one td_left" data-th="First Name">
#   ERIC
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   WAYNE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   B
#  </td>
#  <td class="one td_right" data-th="Age">
#   51
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=6090&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   DAVID
#  </td>
#  <td class="two td_left" data-th="First Name">
#   JACK
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   ALLEN
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   25
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=64058&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   DAVIS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   RAQUEL
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   ELIZABETH
#  </td>
#  <td class="one td_left" data-th="Sex">
#   F
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   29
#  </td>
#  <td class="one td_left" data-th="City">
#   HALLSVILLE
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=77173&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   DAVIS
#  </td>
#  <td class="two td_left" data-th="First Name">
#   RONNELL
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   B
#  </td>
#  <td class="two td_right" data-th="Age">
#   21
#  </td>
#  <td class="two td_left" data-th="City">
#   KANSAS CITY
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80782&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   DEACON
#  </td>
#  <td class="one td_left" data-th="First Name">
#   DUSTIN
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   ODALE
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   26
#  </td>
#  <td class="one td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=56406&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   DEFRANCESCO
#  </td>
#  <td class="two td_left" data-th="First Name">
#   FRANK
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   ANGELO
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   32
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=81469&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   DELOSDIOS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JOSE
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   MIGUEL
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   H
#  </td>
#  <td class="one td_right" data-th="Age">
#   38
#  </td>
#  <td class="one td_left" data-th="City">
#   BRONX CITY
#  </td>
#  <td class="one td_left" data-th="State">
#   NY
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=75665&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   DEVINE
#  </td>
#  <td class="two td_left" data-th="First Name">
#   STEVEN
#  </td>
#  <td class="two td_left" data-th="Middle Name">
#   PATRICK
#  </td>
#  <td class="two td_left" data-th="Sex">
#   M
#  </td>
#  <td class="two td_left" data-th="Race">
#   W
#  </td>
#  <td class="two td_right" data-th="Age">
#   42
#  </td>
#  <td class="two td_left" data-th="City">
#   COLUMBIA
#  </td>
#  <td class="two td_left" data-th="State">
#   MO
#  </td>
#  <td class="two td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=80870&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="tr-paging">
#  <th class="th_left paging_row bottomPaging" colspan="93">
#   Detainee Count: 218
#   <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
#    <ul>
#     <li>
#      <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)">
#       <i class="fa fa-angle-double-left fa-large">
#       </i>
#      </a>
#     </li>
#     <li>
#      <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)">
#       <i class="fa fa-angle-left fa-large">
#       </i>
#      </a>
#     </li>
#     <li class="disabled">
#      <a href="#">
#       Page 1 of 5
#      </a>
#     </li>
#     <li>
#      <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)">
#       <i class="fa fa-angle-right fa-large">
#       </i>
#      </a>
#     </li>
#     <li>
#      <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)">
#       <i class="fa fa-angle-double-right fa-large">
#       </i>
#      </a>
#     </li>
#    </ul>
#   </div>
#  </th>
# </tr>
# C:\Users\karls\Anaconda2\envs\py36\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\karls\Anaconda2\envs\py36\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# You’ll now see each row printed out separately as the script loops through the table.
#
# **Next, loop through each of the cells in each row** by selecting them inside the loop. Cells are created in HTML by the *&lt;td&gt;* tag.

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

for row in table.findAll('tr'):
    for cell in row.findAll('td'):  # NEW CODE
        print (cell.text)
# Out:
# ACTON
# ANTHONY
# SEAN
# M
# B
# 26
# COLUMBIA
# MO
#
#  Details
#
# AKERS
# SYDNEY
# RAE
# F
# W
# 21
# COLUMBIA
# MO
#
#  Details
#
# ALEXANDER
# BENJAMIN
# FRANKLIN
# M
# B
# 23
# COLUMBIA
# MO
#
#  Details
#
# ANDERSON
# ANTHONY
# CURTIS
# M
# W
# 26
# NEVADA
# MO
#
#  Details
#
# ARMSTRONG
# ANTIONE
# LAMONT
# M
# B
# 18
# COLUMBIA
# MO
#
#  Details
#
# AULL
# JONATHAN
# MORGAN
# M
# W
# 37
# COLUMBIA
# MO
#
#  Details
#
# BAKER
# CHRISTOPHER
# ALAN
# M
# W
# 28
# COLUMBIA
# MO
#
#  Details
#
# BAKER
# MICHAEL
# COREY
# M
# B
# 27
# COLUMBIA
# MO
#
#  Details
#
# BANNERMAN
# KRYSTAL
# MARIE
# F
# W
# 30
# CENTRALIA
# MO
#
#  Details
#
# BARNES
# DARIUS
# JOSHUA
# M
# B
# 22
# COLUMBIA
# MO
#
#  Details
#
# BARTZ-OWENS
# ASHLEY
# SUE
# F
# W
# 32
# COLUMBIA
# MO
#
#  Details
#
# BECK
# JOSHUA
# ALEX
# M
# W
# 25
# COLUMBIA
# MO
#
#  Details
#
# BENEDETTI
# FRANK
# DOMINICK
# M
# W
# 29
# COLUMBIA
# MO
#
#  Details
#
# BETTS
# VITA
# LAMETA
# F
# B
# 45
# COLUMBIA
# MO
#
#  Details
#
# BLAIR
# CONNIE
# MARIE
# F
# B
# 36
# COLDWATER
# MS
#
#  Details
#
# BLEVINS
# JESSE
# RAY
# M
# W
# 29
# COLUMBIA
# MO
#
#  Details
#
# BOND
# SOPHIA
# LYNN
# F
# W
# 24
# COLUMBIA
# MO
#
#  Details
#
# BOWEN
# JAMIE
# ROGER
# M
# W
# 38
# HIGBEE
# MO
#
#  Details
#
# BRADLEY
# JAMIE
# MICHELLE
# F
# W
# 33
# COLUMBIA
# MO
#
#  Details
#
# BRADSHAW
# JOSEPH
# LEE
# M
# W
# 42
# COLUMBIA
# MO
#
#  Details
#
# BRESEE
# JAMES
# ANTONIO
# M
# W
# 36
# COLUMBIA
# MO
#
#  Details
#
# BRILL
# BRANDON
# NICHOLAS
# M
# W
# 27
# CLARK
# MO
#
#  Details
#
# BROWN
# AARON
# MICHAEL
# M
# W
# 37
# AKENY
# IA
#
#  Details
#
# BROWN
# BARRY
# RONELL
# M
# B
# 31
# FLORISSANT
# MO
#
#  Details
#
# BROWN
# JEREMIAH
# EZEKIEL
# M
# B
# 33
# COLUMBIA
# MO
#
#  Details
#
# BRYANT
# KYLE
# JAMES
# M
# B
# 28
# COLUMBIA
# MO
#
#  Details
#
# BUCKNER
# KEVIN
# MAURICE
# M
# B
# 18
# COLUMBIA
# MO
#
#  Details
#
# BUTLER
# JEMELL
# DUPRUE
# M
# B
# 22
# JEFFERSON CITY
# MO
#
#  Details
#
# BUTLER
# KEIRAN
# DONOVAN
# M
# W
# 19
# COLUMBIA
# MO
#
#  Details
#
# CALVERT
# JOHN
# RAY
# M
# W
# 36
# COLUMBIA
# MO
#
#  Details
#
# CAMPBELL
# OTIS
# LEE
# M
# B
# 22
# COLUMBIA
# MO
#
#  Details
#
# CAMPBELL
# WILLEM
# DAKOTAH
# M
# W
# 24
# STOVER
# MO
#
#  Details
#
# CANFIELD
# NATHAN
# EDWARD
# M
# W
# 36
# COLUMBIA
# MO
#
#  Details
#
# CARTER
# DARIAN
# MAURICE
# M
# B
# 25
# COLUMBIA
# MO
#
#  Details
#
# CAUDLE
# LINDA
# JOYCE
# F
# W
# 56
# COLUMBIA
# MO
#
#  Details
#
# CELEDON-FLOCK
# ARMANDO
# AGUIRRE
# M
# W
# 30
# RIALTO
# CA
#
#  Details
#
# CHEATOM
# DARIEN
# CAPRI
# M
# B
# 24
# COLUMBIA
# MO
#
#  Details
#
# CHILTON
# CHRISTIAN
# TYLER
# M
# W
# 22
# COLUMBIA
# MO
#
#  Details
#
# CHRISTMAS
# JUSTIN
# LYNN
# M
# W
# 42
# COLUMBIA
# MO
#
#  Details
#
# COMMANDER
# JAVANTE
# BRUCE
# M
# B
# 23
# COLUMBIA
# MO
#
#  Details
#
# CROY
# MARANDA
# LEE
# F
# W
# 32
# COLUMBIA
# MO
#
#  Details
#
# CRUMP
# VICTOR
# EUGENE
# M
# B
# 31
# COLUMBIA
# MO
#
#  Details
#
# CURETON
# ERIC
# WAYNE
# M
# B
# 51
# COLUMBIA
# MO
#
#  Details
#
# DAVID
# JACK
# ALLEN
# M
# W
# 25
# COLUMBIA
# MO
#
#  Details
#
# DAVIS
# RAQUEL
# ELIZABETH
# F
# W
# 29
# HALLSVILLE
# MO
#
#  Details
#
# DAVIS
# RONNELL
#
# M
# B
# 21
# KANSAS CITY
# MO
#
#  Details
#
# DEACON
# DUSTIN
# ODALE
# M
# W
# 26
# COLUMBIA
# MO
#
#  Details
#
# DEFRANCESCO
# FRANK
# ANGELO
# M
# W
# 32
# COLUMBIA
# MO
#
#  Details
#
# DELOSDIOS
# JOSE
# MIGUEL
# M
# H
# 38
# BRONX CITY
# NY
#
#  Details
#
# DEVINE
# STEVEN
# PATRICK
# M
# W
# 42
# COLUMBIA
# MO
#
#  Details
# C:\Users\karls\Anaconda2\envs\py36\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\karls\Anaconda2\envs\py36\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# Everything should be much better.
#
# Now that we have found the data we want to extract, we need to **structure the data in a way that can be written out to a comma-delimited text file**. That won’t be hard since CSVs aren’t any more than a grid of columns and rows, much like a table.
#
# Let’s **start by adding each cell in a row to a new Python list**.

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

for row in table.findAll('tr'):
    list_of_cells = []                             # NEW CODE
    for cell in row.findAll('td'):
        text = cell.text.replace('&nbsp;', '')
        list_of_cells.append(text)                 # NEW CODE
    print (list_of_cells)
# Out:
# ['ACTON', 'ANTHONY', 'SEAN', 'M', 'B', '26', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['AKERS', 'SYDNEY', 'RAE', 'F', 'W', '21', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['ALEXANDER', 'BENJAMIN', 'FRANKLIN', 'M', 'B', '23', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['ANDERSON', 'ANTHONY', 'CURTIS', 'M', 'W', '26', 'NEVADA', 'MO', '\n\xa0Details\n']
# ['ARMSTRONG', 'ANTIONE', 'LAMONT', 'M', 'B', '18', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['AULL', 'JONATHAN', 'MORGAN', 'M', 'W', '37', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BAKER', 'CHRISTOPHER', 'ALAN', 'M', 'W', '28', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BAKER', 'MICHAEL', 'COREY', 'M', 'B', '27', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BANNERMAN', 'KRYSTAL', 'MARIE', 'F', 'W', '30', 'CENTRALIA', 'MO', '\n\xa0Details\n']
# ['BARNES', 'DARIUS', 'JOSHUA', 'M', 'B', '22', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BARTZ-OWENS', 'ASHLEY', 'SUE', 'F', 'W', '32', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BECK', 'JOSHUA', 'ALEX', 'M', 'W', '25', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BENEDETTI', 'FRANK', 'DOMINICK', 'M', 'W', '29', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BETTS', 'VITA', 'LAMETA', 'F', 'B', '45', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BLAIR', 'CONNIE', 'MARIE', 'F', 'B', '36', 'COLDWATER', 'MS', '\n\xa0Details\n']
# ['BLEVINS', 'JESSE', 'RAY', 'M', 'W', '29', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BOND', 'SOPHIA', 'LYNN', 'F', 'W', '24', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BOWEN', 'JAMIE', 'ROGER', 'M', 'W', '38', 'HIGBEE', 'MO', '\n\xa0Details\n']
# ['BRADLEY', 'JAMIE', 'MICHELLE', 'F', 'W', '33', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BRADSHAW', 'JOSEPH', 'LEE', 'M', 'W', '42', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BRESEE', 'JAMES', 'ANTONIO', 'M', 'W', '36', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BRILL', 'BRANDON', 'NICHOLAS', 'M', 'W', '27', 'CLARK', 'MO', '\n\xa0Details\n']
# ['BROWN', 'AARON', 'MICHAEL', 'M', 'W', '37', 'AKENY', 'IA', '\n\xa0Details\n']
# ['BROWN', 'BARRY', 'RONELL', 'M', 'B', '31', 'FLORISSANT', 'MO', '\n\xa0Details\n']
# ['BROWN', 'JEREMIAH', 'EZEKIEL', 'M', 'B', '33', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BRYANT', 'KYLE', 'JAMES', 'M', 'B', '28', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BUCKNER', 'KEVIN', 'MAURICE', 'M', 'B', '18', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['BUTLER', 'JEMELL', 'DUPRUE', 'M', 'B', '22', 'JEFFERSON CITY', 'MO', '\n\xa0Details\n']
# ['BUTLER', 'KEIRAN', 'DONOVAN', 'M', 'W', '19', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CALVERT', 'JOHN', 'RAY', 'M', 'W', '36', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CAMPBELL', 'OTIS', 'LEE', 'M', 'B', '22', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CAMPBELL', 'WILLEM', 'DAKOTAH', 'M', 'W', '24', 'STOVER', 'MO', '\n\xa0Details\n']
# ['CANFIELD', 'NATHAN', 'EDWARD', 'M', 'W', '36', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CARTER', 'DARIAN', 'MAURICE', 'M', 'B', '25', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CAUDLE', 'LINDA', 'JOYCE', 'F', 'W', '56', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CELEDON-FLOCK', 'ARMANDO', 'AGUIRRE', 'M', 'W', '30', 'RIALTO', 'CA', '\n\xa0Details\n']
# ['CHEATOM', 'DARIEN', 'CAPRI', 'M', 'B', '24', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CHILTON', 'CHRISTIAN', 'TYLER', 'M', 'W', '22', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CHRISTMAS', 'JUSTIN', 'LYNN', 'M', 'W', '42', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['COMMANDER', 'JAVANTE', 'BRUCE', 'M', 'B', '23', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CROY', 'MARANDA', 'LEE', 'F', 'W', '32', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CRUMP', 'VICTOR', 'EUGENE', 'M', 'B', '31', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['CURETON', 'ERIC', 'WAYNE', 'M', 'B', '51', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['DAVID', 'JACK', 'ALLEN', 'M', 'W', '25', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['DAVIS', 'RAQUEL', 'ELIZABETH', 'F', 'W', '29', 'HALLSVILLE', 'MO', '\n\xa0Details\n']
# ['DAVIS', 'RONNELL', ' ', 'M', 'B', '21', 'KANSAS CITY', 'MO', '\n\xa0Details\n']
# ['DEACON', 'DUSTIN', 'ODALE', 'M', 'W', '26', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['DEFRANCESCO', 'FRANK', 'ANGELO', 'M', 'W', '32', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# ['DELOSDIOS', 'JOSE', 'MIGUEL', 'M', 'H', '38', 'BRONX CITY', 'NY', '\n\xa0Details\n']
# ['DEVINE', 'STEVEN', 'PATRICK', 'M', 'W', '42', 'COLUMBIA', 'MO', '\n\xa0Details\n']
# []
# C:\Users\karls\Anaconda2\envs\py36\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\karls\Anaconda2\envs\py36\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# Now you should see Python lists streaming by one row at a time.
#
# **Combine the lists into a list**:
#
# Those lists can now be lumped together into one big list of lists. When you think about it, a list of lists isn’t all that different from how a spreadsheet is structured.

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})

list_of_rows = []                            # NEW CODE
for row in table.findAll('tr'):
    list_of_cells = []
    for cell in row.findAll('td'):
        text = cell.text.replace('&nbsp;', '')
        list_of_cells.append(text)
    list_of_rows.append(list_of_cells)       # NEW CODE

print (list_of_rows)
# Out:
# [['ACTON', 'ANTHONY', 'SEAN', 'M', 'B', '26', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['AKERS', 'SYDNEY', 'RAE', 'F', 'W', '21', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['ALEXANDER', 'BENJAMIN', 'FRANKLIN', 'M', 'B', '23', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['ANDERSON', 'ANTHONY', 'CURTIS', 'M', 'W', '26', 'NEVADA', 'MO', '\n\xa0Details\n'], ['ARMSTRONG', 'ANTIONE', 'LAMONT', 'M', 'B', '18', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['AULL', 'JONATHAN', 'MORGAN', 'M', 'W', '37', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BAKER', 'CHRISTOPHER', 'ALAN', 'M', 'W', '28', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BAKER', 'MICHAEL', 'COREY', 'M', 'B', '27', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BANNERMAN', 'KRYSTAL', 'MARIE', 'F', 'W', '30', 'CENTRALIA', 'MO', '\n\xa0Details\n'], ['BARNES', 'DARIUS', 'JOSHUA', 'M', 'B', '22', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BARTZ-OWENS', 'ASHLEY', 'SUE', 'F', 'W', '32', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BECK', 'JOSHUA', 'ALEX', 'M', 'W', '25', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BENEDETTI', 'FRANK', 'DOMINICK', 'M', 'W', '29', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BETTS', 'VITA', 'LAMETA', 'F', 'B', '45', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BLAIR', 'CONNIE', 'MARIE', 'F', 'B', '36', 'COLDWATER', 'MS', '\n\xa0Details\n'], ['BLEVINS', 'JESSE', 'RAY', 'M', 'W', '29', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BOND', 'SOPHIA', 'LYNN', 'F', 'W', '24', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BOWEN', 'JAMIE', 'ROGER', 'M', 'W', '38', 'HIGBEE', 'MO', '\n\xa0Details\n'], ['BRADLEY', 'JAMIE', 'MICHELLE', 'F', 'W', '33', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BRADSHAW', 'JOSEPH', 'LEE', 'M', 'W', '42', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BRESEE', 'JAMES', 'ANTONIO', 'M', 'W', '36', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BRILL', 'BRANDON', 'NICHOLAS', 'M', 'W', '27', 'CLARK', 'MO', '\n\xa0Details\n'], ['BROWN', 'AARON', 'MICHAEL', 'M', 'W', '37', 'AKENY', 'IA', '\n\xa0Details\n'], ['BROWN', 'BARRY', 'RONELL', 'M', 'B', '31', 'FLORISSANT', 'MO', '\n\xa0Details\n'], ['BROWN', 'JEREMIAH', 'EZEKIEL', 'M', 'B', '33', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BRYANT', 'KYLE', 'JAMES', 'M', 'B', '28', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BUCKNER', 'KEVIN', 'MAURICE', 'M', 'B', '18', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['BUTLER', 'JEMELL', 'DUPRUE', 'M', 'B', '22', 'JEFFERSON CITY', 'MO', '\n\xa0Details\n'], ['BUTLER', 'KEIRAN', 'DONOVAN', 'M', 'W', '19', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CALVERT', 'JOHN', 'RAY', 'M', 'W', '36', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CAMPBELL', 'OTIS', 'LEE', 'M', 'B', '22', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CAMPBELL', 'WILLEM', 'DAKOTAH', 'M', 'W', '24', 'STOVER', 'MO', '\n\xa0Details\n'], ['CANFIELD', 'NATHAN', 'EDWARD', 'M', 'W', '36', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CARTER', 'DARIAN', 'MAURICE', 'M', 'B', '25', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CAUDLE', 'LINDA', 'JOYCE', 'F', 'W', '56', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CELEDON-FLOCK', 'ARMANDO', 'AGUIRRE', 'M', 'W', '30', 'RIALTO', 'CA', '\n\xa0Details\n'], ['CHEATOM', 'DARIEN', 'CAPRI', 'M', 'B', '24', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CHILTON', 'CHRISTIAN', 'TYLER', 'M', 'W', '22', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CHRISTMAS', 'JUSTIN', 'LYNN', 'M', 'W', '42', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['COMMANDER', 'JAVANTE', 'BRUCE', 'M', 'B', '23', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CROY', 'MARANDA', 'LEE', 'F', 'W', '32', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CRUMP', 'VICTOR', 'EUGENE', 'M', 'B', '31', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['CURETON', 'ERIC', 'WAYNE', 'M', 'B', '51', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['DAVID', 'JACK', 'ALLEN', 'M', 'W', '25', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['DAVIS', 'RAQUEL', 'ELIZABETH', 'F', 'W', '29', 'HALLSVILLE', 'MO', '\n\xa0Details\n'], ['DAVIS', 'RONNELL', ' ', 'M', 'B', '21', 'KANSAS CITY', 'MO', '\n\xa0Details\n'], ['DEACON', 'DUSTIN', 'ODALE', 'M', 'W', '26', 'COLUMBIA', 'MO', '\n\xa0Details\n'], ['DEF ...
# C:\Users\karls\Anaconda2\envs\py36\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\karls\Anaconda2\envs\py36\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# The output is a dump of a big bunch of data. Look closely and you’ll see the list of lists.
#
# **Write output to csv file**:
#  1. At the top of the file, **import Python’s built-in csv module**.
#  2. At the botton:
#   - **Create a new file**
#   - **Hand off the file** to the csv module
#   - Use the csv module's **_writerows_ to dump out our list of lists**.

# %%
import csv                                      # NEW CODE
import requests
from bs4 import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html, "lxml")
table = soup.find('tbody', attrs={'class': 'stripe'})

list_of_rows = []
for row in table.findAll('tr'):
    list_of_cells = []
    for cell in row.findAll('td'):
        text = cell.text.replace('&nbsp;', '')
        list_of_cells.append(text)
    list_of_rows.append(list_of_cells)

outfile = open("./inmates.csv", "w")           # NEW CODE
writer = csv.writer(outfile)                   # NEW CODE
writer.writerows(list_of_rows)                 # NEW CODE
outfile.close()                                # NEW CODE

# %% [markdown]
# Nothing should happen – at least to appear to happen.
#
# Since there are no longer any print statements in the file, the script is no longer dumping data out to your terminal. However, if you open up your code directory you should now see a new file named inmates.csv waiting for you. Open it in a text editor or Excel and you should see structured data all scraped out.
#
# There is still one obvious problem though. **There are no headers**.
#
# Here’s why. If you go back and look closely, **our script is only looping through lists of _&lt;td&gt;_ tags found within each row**. Fun fact: **Header tags in HTML tables are often wrapped in the slightly different _&lt;th&gt;_ tag**. Look back at the source of the Boone County page and you’ll see that’s what exactly they do.
#
# But rather than bend over backwords to dig them out of the page, let’s try something a little different. Let’s just skip the first row when we loop though, and then **write the headers out ourselves at the end**.

# %%
import csv
import requests
from bs4 import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html, "lxml")
table = soup.find('tbody', attrs={'class': 'stripe'})

list_of_rows = []
for row in table.findAll('tr')[1:]:
    list_of_cells = []
    for cell in row.findAll('td'):
        text = cell.text.replace('&nbsp;', '')
        list_of_cells.append(text)
    list_of_rows.append(list_of_cells)

outfile = open("./inmates.csv", "w")
writer = csv.writer(outfile)
writer.writerow(["Last", "First", "Middle", "Gender", "Race", "Age", "City", "State"])
writer.writerows(list_of_rows)
outfile.close()
